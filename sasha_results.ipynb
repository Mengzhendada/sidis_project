# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
column_names=['q2','x','z','pt2','r1','r2','r3','r4','r5','r6']
df_z1_sasha=pd.read_csv('inputs/sasha/01.z1.dat',delim_whitespace=True,names=column_names)
df_z1_sasha.head()
# Out:
#      q2      x     z      pt2        r1        r2        r3        r4
# 0  1.83  0.138  0.22  0.01500  0.003702  0.004074  0.004368  0.001620  \
# 1  1.83  0.138  0.22  0.16111  0.013699  0.014740  0.017006  0.006199
# 2  1.83  0.138  0.22  0.30722  0.018206  0.019379  0.023285  0.007801
# 3  1.83  0.138  0.22  0.45333  0.021948  0.022991  0.027735  0.008451
# 4  1.83  0.138  0.22  0.59944  0.024216  0.024720  0.030226  0.009236
#
#          r5        r6
# 0  0.001711  0.001557
# 1  0.006567  0.005185
# 2  0.008373  0.006126
# 3  0.009278  0.007520
# 4  0.010394  0.010074

# %%
column_names=['q2','x','z','pt2','r1','r2','r3','r4','r5','r6']
df_z2_sasha=pd.read_csv('inputs/sasha/01.z2.dat',delim_whitespace=True,names=column_names)
df_z2_sasha.head()
# Out:
#      q2      x      z      pt2        r1        r2        r3        r4
# 0  1.83  0.138  0.495  0.01500  0.010966  0.011402  0.011459  0.003472  \
# 1  1.83  0.138  0.495  0.16111  0.034076  0.035127  0.035324  0.011249
# 2  1.83  0.138  0.495  0.30722  0.042914  0.043867  0.044215  0.014343
# 3  1.83  0.138  0.495  0.45333  0.047738  0.048280  0.048894  0.016294
# 4  1.83  0.138  0.495  0.59944  0.050842  0.050727  0.051809  0.018126
#
#          r5        r6
# 0  0.003487  0.003452
# 1  0.011368  0.011263
# 2  0.014524  0.014461
# 3  0.016564  0.016640
# 4  0.018475  0.018838

# %%
column_names=['q2','x','z','pt2','r1','r2','r3','r4','r5','r6']
df_z3_sasha=pd.read_csv('inputs/sasha/01.z3.dat',delim_whitespace=True,names=column_names)
df_z3_sasha.head()
# Out:
#      q2      x     z      pt2        r1        r2        r3        r4
# 0  1.83  0.138  0.77  0.01500  0.019437  0.019766  0.019674  0.003788  \
# 1  1.83  0.138  0.77  0.16111  0.056249  0.057022  0.056719  0.012221
# 2  1.83  0.138  0.77  0.30722  0.067568  0.068271  0.067820  0.016449
# 3  1.83  0.138  0.77  0.45333  0.071654  0.072095  0.071503  0.019315
# 4  1.83  0.138  0.77  0.59944  0.072730  0.072804  0.072063  0.021369
#
#          r5        r6
# 0  0.003777  0.003802
# 1  0.012176  0.012363
# 2  0.016380  0.016829
# 3  0.019244  0.020125
# 4  0.021291  0.022901

# %%
plt.plot(df_z1_sasha['pt2'],df_z1_sasha['r1'],color='black')
plt.plot(df_z1_sasha['pt2'],df_z1_sasha['r2'],color='blue')
plt.plot(df_z1_sasha['pt2'],df_z1_sasha['r3'],color='red')

plt.xlim(0,1)
plt.xlabel(r'$p_t^2(GeV^2)$')
plt.ylabel(r'$A_{UT}^{sin(\phi_h-\phi_s)}$')
plt.ylim(0,0.1)
plt.text(0.5, 0.02, f'$z: {df_z1_sasha["z"].iloc[0]}$', 
         horizontalalignment='center', verticalalignment='center')

plt.plot(df_z2_sasha['pt2'],df_z2_sasha['r1'],color='black')
plt.plot(df_z2_sasha['pt2'],df_z2_sasha['r2'],color='blue')
plt.plot(df_z2_sasha['pt2'],df_z2_sasha['r3'],color='red')
plt.text(0.5, 0.04, f'$z: {df_z2_sasha["z"].iloc[0]}$', 
         horizontalalignment='center', verticalalignment='center')

plt.plot(df_z3_sasha['pt2'],df_z3_sasha['r1'],color='black')
plt.plot(df_z3_sasha['pt2'],df_z3_sasha['r2'],color='blue')
plt.plot(df_z3_sasha['pt2'],df_z3_sasha['r3'],color='red')
plt.text(0.5, 0.07, f'$z: {df_z3_sasha["z"].iloc[0]}$', 
         horizontalalignment='center', verticalalignment='center')

plt.text(0.5, 0.1, f'$Q^2: {df_z1_sasha["q2"].iloc[0]}; x: {df_z1_sasha["x"].iloc[0]}$', 
         horizontalalignment='center', verticalalignment='center', transform=plt.gca().transAxes)

plt.savefig('inputs/sasha/siver_z1.pdf')

# %%
plt.plot(df_z1_sasha['pt2'],df_z1_sasha['r4'],color='black')
plt.plot(df_z1_sasha['pt2'],df_z1_sasha['r5'],color='blue')
plt.plot(df_z1_sasha['pt2'],df_z1_sasha['r6'],color='red')
plt.xlim(0,1)
plt.xlabel(r'$p_t^2(GeV^2)$')
plt.ylabel(r'$A_{UT}^{sin(\phi_h+\phi_s)}$')
plt.ylim(0,0.03)
plt.text(0.5, 0.01, f'$z: {df_z1_sasha["z"].iloc[0]}$', 
         horizontalalignment='center', verticalalignment='center')

plt.plot(df_z2_sasha['pt2'],df_z2_sasha['r4'],color='black')
plt.plot(df_z2_sasha['pt2'],df_z2_sasha['r5'],color='blue')
plt.plot(df_z2_sasha['pt2'],df_z2_sasha['r6'],color='red')
plt.text(0.5, 0.015, f'$z: {df_z2_sasha["z"].iloc[0]}$', 
         horizontalalignment='center', verticalalignment='center')

plt.plot(df_z3_sasha['pt2'],df_z3_sasha['r4'],color='black')
plt.plot(df_z3_sasha['pt2'],df_z3_sasha['r5'],color='blue')
plt.plot(df_z3_sasha['pt2'],df_z3_sasha['r6'],color='red')
plt.text(0.5, 0.022, f'$z: {df_z3_sasha["z"].iloc[0]}$', 
         horizontalalignment='center', verticalalignment='center')




plt.text(0.5, 0.15, f'$Q^2: {df_z1_sasha["q2"].iloc[0]}; x: {df_z1_sasha["x"].iloc[0]}$', 
         horizontalalignment='center', verticalalignment='center', transform=plt.gca().transAxes)
plt.savefig('inputs/sasha/collin_z1.pdf')
